# %%
from ultralytics import YOLO, checks, hub
import cv2
import os
from dotenv import load_dotenv

# %%
load_dotenv(dotenv_path='./src/.env')
hub.login(os.getenv('YOLO_KEY'))
print(os.getenv('YOLO_KEY'))
model = YOLO('https://hub.ultralytics.com/models/hxfqhc9M08eDx2MJKO7q')
# Out:
# Ultralytics HUB: New authentication successful
# 662ece087f22297d1c7d88be3a2f0e8286f59ca9c5
# Loading trained HUB model https://hub.ultralytics.com/models/hxfqhc9M08eDx2MJKO7q
# ...
# 100%|██████████| 5.20M/5.20M [00:00<00:00, 13.9MB/s]

# %%
# Train model
# Warning: This will take a LONG time to run. Expected run time is upwards of 3 hours depending on hardware.
model.train()
# Out:
# New https://pypi.org/project/ultralytics/8.3.71 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.65  Python-3.12.1 torch-2.5.1+cpu CPU (AMD Ryzen 7 7800X3D 8-Core Processor)
# ...

# %%
# Validate
results = model.val(
    data='./data.yaml',       # Path to data.yaml
    batch=16,                 # Batch size
    imgsz=640                 # Image size
    conf=0.25             # Confidence threshold for predictions
    lr=0.01           # Learning rate for training
    epochs=50          # Number of epochs to train
)
print("Validation Results:", results)
# Out:
# Ultralytics 8.3.29  Python-3.12.1 torch-2.2.2+cpu CPU (AMD Ryzen 7 7800X3D 8-Core Processor)
# YOLO11s summary (fused): 238 layers, 9,415,122 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning C:\Users\conno\Desktop\temp_repos\Major_Project\datasets\valid\labels.cache... 396 images, 2 backgrounds, 0 corrupt: 100%|██████████| 396/396 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:39<00:00,  1.57s/it]
#                    all        396       1312      0.717       0.68      0.713      0.432
#                Running         19         25       0.56       0.12      0.222     0.0948
#                Walking        146        266      0.619      0.703      0.722      0.423
#            laying_down        226        322      0.886      0.963      0.971      0.682
#            not_defined        144        189      0.696      0.704      0.735      0.387
# ...

# %%
cap = cv2.VideoCapture('./data/footage/drone_footage.mp4')

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Inference on a single frame
    results = model(frame)

    # Draw bounding boxes
    for r in results:
        for box, confidence, cls in zip(r.boxes.xyxy, r.boxes.conf, r.boxes.cls):
            x1, y1, x2, y2 = map(int, box)
            label = f"{model.names[int(cls)]} {confidence:.2f}"
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    cv2.imshow("Drone Footage", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 65.8ms
# Speed: 1.5ms preprocess, 65.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.3ms
# Speed: 0.0ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.6ms
# Speed: 0.0ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
